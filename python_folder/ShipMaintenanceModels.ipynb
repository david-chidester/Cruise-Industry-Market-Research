# %%
import pandas as pd

#creating data frame combining both csv files
shipMaintenanceFrame = pd.read_csv('raw_data/Ship_Maintenance_1.csv')
#frame2 = pd.read_csv('raw_data/Ship_Maintenance_2.csv')

#shipMaintenanceFrame.append(frame2)

print(shipMaintenanceFrame)
# Out:
#        Fiscal Period Complete Date Service Order ID Notification ID  \
# 0            2018-01      1/5/2018         50006519       304645087
# 1            2018-01      1/5/2018         50006519       304645087
# 2            2018-01      1/8/2018         50006616       304645104
# 3            2018-01      1/8/2018         50006616       304645104
# 4            2018-01      1/8/2018         50006616       304645104
# 5            2018-01      1/8/2018         50006616       304645104
# 6            2018-01      1/8/2018         50006616       304645104
# 7            2018-01      1/8/2018         50006616       304645104
# 8            2018-01      1/8/2018         50006616       304645104
# 9            2018-01      1/8/2018         50006616       304645104
# 10           2018-01      1/8/2018         50006616       304645104
# 11           2018-01     1/22/2018         50006618       304645106
# 12           2018-01     1/22/2018         50006618       304645106
# ...
