# %%
# %matplotlib inline
#%config InlineBackend.figure_format = 'svg'

import numpy as np
import matplotlib.pyplot as plt
pi = np.pi
x = np.linspace(-4*pi, 4*pi, 1000)

plt.plot(x, np.sin(x)/x)
plt.show()

# %%
import pandas as pd

# %%
objname = pd.read_csv("AFS.csv")

# %%
objname.head()
# Out:
#    Year  RevMil  GProfitMil  OpIncMil  EBITDAMil  NetIncMil  EarningPerShare  \
# 0  2018   18881        7791      3324       5341       3152             4.44
# 1  2017   17510        7009      2809       4655       2606             3.59
# 2  2016   16389        7006      3071       4809       2779             3.72
# 3  2015   15714        6267      2574       4200       1757             2.26
# 4  2014   15884        5463      1772       3409       1216             1.56
#
#    SharesOutMil  AvgStkPrice  YearOpen  YearHigh  YearLow  YearClose  \
# 0           710      60.7217   64.1750   69.1647  45.8169    48.8806
# 1           725      59.6774   48.8753   66.3526  48.8753    63.8096
# 2           747      44.7539   49.4207   50.0001  38.2235    48.8003
# 3           779      43.9725   40.6589   50.2778  38.0202    49.6760
# 4           778      34.5834   34.6036   40.9620  30.0218    40.4093
#
#    AnnPerChg
# 0     -23.40
# 1      30.76
# 2      -1.76
# 3      22.93
# 4      15.73

# %%
objname
# Out:
#     Year  RevMil  GProfitMil  OpIncMil  EBITDAMil  NetIncMil  EarningPerShare  \
# 0   2018   18881        7791      3324       5341       3152             4.44
# 1   2017   17510        7009      2809       4655       2606             3.59
# 2   2016   16389        7006      3071       4809       2779             3.72
# 3   2015   15714        6267      2574       4200       1757             2.26
# 4   2014   15884        5463      1772       3409       1216             1.56
# 5   2013   15456        4811      1329       2919       1055             1.36
# 6   2012   15382        5062      1642       3169       1298             1.67
# 7   2011   15793        5494      2255       3777       1912             2.42
# 8   2010   14469        5377      2347       3763       1978             2.47
# 9   2009   13460        5053      2154       3463       1790             2.24
# 10  2008   14947        5607      2729       3978       2324             2.90
# ...

# %%
objname(0, 6)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-31a8a911baf6> in <module>
# ----> 1 objname(0, 6)
#
# TypeError: 'DataFrame' object is not callable

# %%
xaxis = Year
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-a5f03e27bd78> in <module>
# ----> 1 xaxis = Year
#
# NameError: name 'Year' is not defined

# %%
pd.DataFrame.plot(x='Year', y='GProfitMil')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-a494fc3d3150> in <module>
# ----> 1 pd.DataFrame.plot(x='Year', y='GProfitMil')
#
# TypeError: __init__() got an unexpected keyword argument 'x'

# %%
plt.scatter(df['Year'], df['GProfitMil'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-58d106ab751a> in <module>
# ----> 1 plt.scatter(df['Year'], df['GProfitMil'])
#
# NameError: name 'df' is not defined

# %%
df = pd.DataFrame(objname)

# %%
df.plot(x='Year',y='GProfitMil',style='-')

# %%
objname2 = pd.read_csv("QFS.csv")

# %%
objname2
# Out:
#     Year Quarter  RevenueMil  GProfitMil  OpIncMil  EBITDAMil  NetIncMil  \
# 0   2019      Q2        4838        1679       516       1059        451
# 1   2019      Q1        4673        1531       386        902        336
# 2   2018      Q4        4456        1714       552       1059        493
# 3   2018      Q3        5836        2878      1794       2304       1707
# 4   2018      Q2        4357        1676       559       1071        561
# 5   2018      Q1        4232        1523       419        907        391
# 6   2017      Q4        4259        1642       548       1026        546
# 7   2017      Q3        5515        2502      1393       1865       1329
# 8   2017      Q2        3945        1509       500        957        379
# 9   2017      Q1        3791        1356       368        807        352
# 10  2016      Q4        3936        1617       597       1032        608
# 11  2016      Q3        5097        2534      1562       2004       1424
# ...

# %%
df2 = pd.DataFrame(objname2)

# %% [markdown]
# df2.loc[df2['Quarter']=='Q1']

# %%
print(df2)
# Out:
#     Year Quarter  RevenueMil  GProfitMil  OpIncMil  EBITDAMil  NetIncMil  \
# 0   2019      Q2        4838        1679       516       1059        451
# 1   2019      Q1        4673        1531       386        902        336
# 2   2018      Q4        4456        1714       552       1059        493
# 3   2018      Q3        5836        2878      1794       2304       1707
# 4   2018      Q2        4357        1676       559       1071        561
# 5   2018      Q1        4232        1523       419        907        391
# 6   2017      Q4        4259        1642       548       1026        546
# 7   2017      Q3        5515        2502      1393       1865       1329
# 8   2017      Q2        3945        1509       500        957        379
# 9   2017      Q1        3791        1356       368        807        352
# 10  2016      Q4        3936        1617       597       1032        608
# 11  2016      Q3        5097        2534      1562       2004       1424
# ...

# %%
Qtr1 = df2.loc[df2['Quarter']=='Q1']

# %%
print(Qtr1)
# Out:
#     Year Quarter  RevenueMil  GProfitMil  OpIncMil  EBITDAMil  NetIncMil  \
# 1   2019      Q1        4673        1531       386        902        336
# 5   2018      Q1        4232        1523       419        907        391
# 9   2017      Q1        3791        1356       368        807        352
# 13  2016      Q1        3651        1408       434        857        142
# 17  2015      Q1        3531        1196       266        667         49
# 21  2014      Q1        3585         993        67        472        -20
# 25  2013      Q1        3593         994       145        534         37
# 29  2012      Q1        3582         888       -82        294       -139
# 33  2011      Q1        3419        1024       235        602        152
# 37  2010      Q1        3178         996       255        600        175
# 41  2009      Q1        2864        1014       311        622        260
# 45  2008      Q1        3152        1038       312        613        236
# ...
